# %% [markdown]
# ## RFInder: plot gifs of set of output plots

# %%
import os, string, sys, glob
import numpy as np
import pyaml, json
import logging
logger = logging.getLogger()
from IPython.display import HTML, display


import rfinder as rfinder
import rfinder_plots as rfi_pl
rfiPL = rfi_pl.rfi_plots()

#animations in notebook
from matplotlib import rc


print '\t+------+\n\t  Done \n\t+------+'
# Out:
# 	+------+
# 	  Done
# 	+------+

# %% [markdown]
# ### Load and modify parameter file

# %%
print '\t+------+\n\t RFInder \n\t Parameter File \n\t+------+'

rfi_par = rfinder.rfinder()

print '\t+------+\n\t Parameters Loaded \n\t+------+'

#print parameter file 
#print(json.dumps(rfi_par.cfg_par, indent=4, sort_keys=True))
# Out:
# INFO:rfinder:	 ... Reading parameter file ...
# 	+------+
# 	 RFInder
# 	 Parameter File
# 	+------+
# 	+------+
# 	 Parameters Loaded
# 	+------+

# %%
# Set working directory & filenames
#rfi_par.cfg_par['general']['workdir'] = '/home/maccagni/RFI/'

# Enable / disable modules
rfi_par.cfg_par['rfi']['enable'] = True
rfi_par.cfg_par['plots']['enable'] = True

#MSFILE
rfi_par.cfg_par['general']['msname'] = ['fa1_conc.ms']
rfi_par.cfg_par['general']['field'] = 1

rfi_par.set_dirs()

# CHUNKS
#create also tables of data binned in frequency and time

#plotting options
rfi_par.cfg_par['plots']['altaz_gif'] = True

print '\t+------+\n\t Parameters modified \n\t+------+'
# Out:
# 	+------+
# 	 Parameters modified
# 	+------+

# %% [markdown]
# ### Alt/Az gifs

# %%
#select files
filenames = glob.glob(rfi_par.cfg_par['general']['altazplotdir']+'/*.png')

if rfi_par.cfg_par['rfi']['use_flags']== True:
    filenames = sorted(filenames, key = lambda x: x.split('flags')[1])
elif cfg_par['rfi']['use_flags']== False:
    filenames = sorted(filenames, key = lambda x: x.split('rfi')[1])

out_animation = rfi_par.cfg_par['general']['plotdir']+'AltAz_movie.mp4'
    
animation_altaz = rfiPL.gif_me_up(rfi_par,filenames,out_animation)



print '\t+------+\n\t Done \n\t+------+'
# Out:
# INFO:rfinder_plots:	 ... Creating movie ...
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', u'-f', u'rawvideo', u'-vcodec', u'rawvideo', u'-s', u'576x576', u'-pix_fmt', u'rgba', u'-r', '5', u'-loglevel', u'quiet', u'-i', u'pipe:', u'-vcodec', 'h264', u'-pix_fmt', u'yuv420p', u'-b', u'3600k', u'-metadata', u'artist=XY', u'-y', '/home/maccagni/FornaxA/MeerKAT/fa1/msdir/rfi/plots/AltAz_movie.mp4']
# INFO:rfinder_plots:	 ... Movie done ...
# 	+------+
# 	 Done
# 	+------+

# %% [markdown]
# ### Time chunks 2D gifs

# %%
#select files
filenames = glob.glob(rfi_par.cfg_par['general']['timeplotdir2D']+'/*.png')

out_animation = rfi_par.cfg_par['general']['plotdir']+'Time_2Dplot_movie.mp4'
    
animation_2d = rfiPL.gif_me_up(rfi_par,filenames,out_animation)



print '\t+------+\n\t Done \n\t+------+'
# Out:
# INFO:rfinder_plots:	 ... Creating movie ...
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', u'-f', u'rawvideo', u'-vcodec', u'rawvideo', u'-s', u'576x576', u'-pix_fmt', u'rgba', u'-r', '5', u'-loglevel', u'quiet', u'-i', u'pipe:', u'-vcodec', 'h264', u'-pix_fmt', u'yuv420p', u'-b', u'3600k', u'-metadata', u'artist=XY', u'-y', '/home/maccagni/FornaxA/MeerKAT/fa1/msdir/rfi/plots/Time_2Dplot_movie.mp4']
# INFO:rfinder_plots:	 ... Movie done ...
# 	+------+
# 	 Done
# 	+------+

# %% [markdown]
# ### Time chunks 1D gifs

# %%
#select files
filenames_flags = glob.glob(rfi_par.cfg_par['general']['timeplotdir1D']+'/flags_*')

out_animation = rfi_par.cfg_par['general']['plotdir']+'TimeChunks_1D_flags.mp4'
animation_flags = rfiPL.gif_me_up(rfi_par,filenames_flags,out_animation)

#select files
filenames_noise = glob.glob(rfi_par.cfg_par['general']['timeplotdir1D']+'/noise_*')

out_animation = rfi_par.cfg_par['general']['plotdir']+'TimeChunks_1D_noise.mp4'
animation_noise = rfiPL.gif_me_up(rfi_par,filenames_noise,out_animation)

filenames_noisefactor = glob.glob(rfi_par.cfg_par['general']['timeplotdir1D']+'/noisefactor_*')

out_animation = rfi_par.cfg_par['general']['plotdir']+'TimeChunks_1Dnoisefactor.mp4'
animation_noisefactor = rfiPL.gif_me_up(rfi_par,filenames_noisefactor,out_animation)



print '\t+------+\n\t Done \n\t+------+'
# Out:
# INFO:rfinder_plots:	 ... Creating movie ...
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', u'-f', u'rawvideo', u'-vcodec', u'rawvideo', u'-s', u'576x576', u'-pix_fmt', u'rgba', u'-r', '5', u'-loglevel', u'quiet', u'-i', u'pipe:', u'-vcodec', 'h264', u'-pix_fmt', u'yuv420p', u'-b', u'3600k', u'-metadata', u'artist=XY', u'-y', '/home/maccagni/FornaxA/MeerKAT/fa1/msdir/rfi/plots/TimeChunks_1D_flags.mp4']
# INFO:rfinder_plots:	 ... Movie done ...
# INFO:rfinder_plots:	 ... Creating movie ...
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', u'-f', u'rawvideo', u'-vcodec', u'rawvideo', u'-s', u'576x576', u'-pix_fmt', u'rgba', u'-r', '5', u'-loglevel', u'quiet', u'-i', u'pipe:', u'-vcodec', 'h264', u'-pix_fmt', u'yuv420p', u'-b', u'3600k', u'-metadata', u'artist=XY', u'-y', '/home/maccagni/FornaxA/MeerKAT/fa1/msdir/rfi/plots/TimeChunks_1D_noise.mp4']
# INFO:rfinder_plots:	 ... Movie done ...
# INFO:rfinder_plots:	 ... Creating movie ...
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', u'-f', u'rawvideo', u'-vcodec', u'rawvideo', u'-s', u'576x576', u'-pix_fmt', u'rgba', u'-r', '5', u'-loglevel', u'quiet', u'-i', u'pipe:', u'-vcodec', 'h264', u'-pix_fmt', u'yuv420p', u'-b', u'3600k', u'-metadata', u'artist=XY', u'-y', '/home/maccagni/FornaxA/MeerKAT/fa1/msdir/rfi/plots/TimeChunks_1Dnoisefactor.mp4']
# INFO:rfinder_plots:	 ... Movie done ...
# 	+------+
# 	 Done
# 	+------+

# %% [markdown]
# ### Show animations

# %%
rc('animation', html='html5')

#Alt/Az
HTML(animation_altaz.to_html5_video())
animation_altaz
# Out:
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', u'-f', u'rawvideo', u'-vcodec', u'rawvideo', u'-s', u'576x576', u'-pix_fmt', u'rgba', u'-r', '1.0', u'-loglevel', u'quiet', u'-i', u'pipe:', u'-vcodec', u'h264', u'-pix_fmt', u'yuv420p', u'-y', u'/tmp/tmpdoPqnk.m4v']
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
#2D
HTML(animation_2d.to_html5_video())
animation_2d
# Out:
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', u'-f', u'rawvideo', u'-vcodec', u'rawvideo', u'-s', u'576x576', u'-pix_fmt', u'rgba', u'-r', '1.0', u'-loglevel', u'quiet', u'-i', u'pipe:', u'-vcodec', u'h264', u'-pix_fmt', u'yuv420p', u'-y', u'/tmp/tmpPlzSi_.m4v']
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
#1D
HTML(animation_flags.to_html5_video())
animation_flags
# Out:
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', u'-f', u'rawvideo', u'-vcodec', u'rawvideo', u'-s', u'576x576', u'-pix_fmt', u'rgba', u'-r', '1.0', u'-loglevel', u'quiet', u'-i', u'pipe:', u'-vcodec', u'h264', u'-pix_fmt', u'yuv420p', u'-y', u'/tmp/tmpSjYmGp.m4v']
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
#1D
HTML(animation_noise.to_html5_video())
animation_noise
# Out:
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', u'-f', u'rawvideo', u'-vcodec', u'rawvideo', u'-s', u'576x576', u'-pix_fmt', u'rgba', u'-r', '1.0', u'-loglevel', u'quiet', u'-i', u'pipe:', u'-vcodec', u'h264', u'-pix_fmt', u'yuv420p', u'-y', u'/tmp/tmp90gaZI.m4v']
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
#1D
HTML(animation_noisefactor.to_html5_video())
animation_noisefactor
# Out:
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter.run: running command: ['ffmpeg', u'-f', u'rawvideo', u'-vcodec', u'rawvideo', u'-s', u'576x576', u'-pix_fmt', u'rgba', u'-r', '1.0', u'-loglevel', u'quiet', u'-i', u'pipe:', u'-vcodec', u'h264', u'-pix_fmt', u'yuv420p', u'-y', u'/tmp/tmpYWSICo.m4v']
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...
